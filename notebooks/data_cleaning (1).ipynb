# %%
import pandas as pd
import numpy as np
import re

df = pd.read_csv('C:/Users/Admin/Downloads/data/raw/VN_housing_dataset.csv')

cols_to_drop = ['Unnamed: 0', 'Ngày', 'Địa chỉ']
df = df.drop(columns=cols_to_drop)

df.columns = [
    'District', 'Ward', 'House_type', 'Legal', 'Floors', 'Bedrooms', 'Area', 'Length', 'Width', 'Price_per_m2'
]

# Hàm làm sạch số (loại bỏ chữ, đổi dấu phẩy thành chấm)
def extract_number(value):
    if pd.isna(value): return np.nan
    # Chuyển về chuỗi thường
    text = str(value).lower()
    # Nếu có dấu phẩy (86,96) thay bằng chấm (86.96)
    text = text.replace(',', '.')
    # Tìm số (bao gồm cả số thập phân)
    match = re.search(r"[-+]?\d*\.\d+|\d+", text)
    if match:
        return float(match.group())
    return np.nan

# Áp dụng cho các cột số
cols_to_clean = ['Area', 'Length', 'Width', 'Price_per_m2', 'Bedrooms', 'Floors']
for col in cols_to_clean:
    df[col] = df[col].apply(extract_number)

# Tính TỔNG GIÁ TRỊ CĂN NHÀ (Đây là cột quan trọng nhất để dự đoán)
# Công thức: Giá/m2 * Diện tích = Tổng giá (đơn vị: Triệu VNĐ)
df['Total_Price_Billion'] = (df['Price_per_m2'] * df['Area']) / 1000
# (Chia 1000 để đổi từ Triệu sang Tỷ cho số nhỏ dễ nhìn)

# Xử lý cột Quận/Huyện (Bỏ chữ 'Quận', 'Phường')
df['District'] = df['District'].str.replace('Quận', '').str.strip()
df['Ward'] = df['Ward'].str.replace('Phường', '').str.replace('Xã', '').str.strip()

# Xử lý thiếu (Missing Values)
# Xóa dòng nếu thiếu Diện tích hoặc Giá (vì không train được)
df = df.dropna(subset=['Area', 'Total_Price_Billion'])

# Cột Pháp lý: Điền 'Dang_cap_nhat'
df['Legal'] = df['Legal'].fillna('Dang_cap_nhat')

# Cột Số tầng, Phòng ngủ: Điền bằng trung vị (Median)
df['Floors'] = df['Floors'].fillna(df['Floors'].median())
df['Bedrooms'] = df['Bedrooms'].fillna(df['Bedrooms'].median())

# Xóa cột Dài, Rộng (vì thiếu quá nhiều)
df = df.drop(columns=['Length', 'Width'])

# Lọc theo Diện tích
# Chỉ lấy nhà từ 10m2 đến 500m2
df = df[(df['Area'] >= 10) & (df['Area'] <= 500)]

# Lọc bỏ số phòng ngủ
# Nếu diện tích < 40m2 mà có >= 8 phòng ngủ -> XÓA (Vì quá chật)
df = df[~((df['Area'] < 40) & (df['Bedrooms'] >= 8))]

# Nếu số tầng < 2 mà có >= 5 phòng ngủ (trừ khi diện tích > 100m2) -> XÓA
df = df[~((df['Floors'] < 2) & (df['Bedrooms'] >= 5) & (df['Area'] < 100))]

# Lọc theo Giá
# Chỉ lấy nhà giá từ 500 Triệu (0.5 tỷ) đến 100 Tỷ
df = df[(df['Total_Price_Billion'] >= 0.5) & (df['Total_Price_Billion'] <= 100)]

# Lưu file sạch

# %%
df.count()
# Out:
# District               81824
# Ward                   81786
# House_type             81795
# Legal                  81825
# Floors                 81825
# Bedrooms               81825
# Area                   81825
# Price_per_m2           81825
# Total_Price_Billion    81825
# dtype: int64

# %%
df.head(10)
# Out:
#        District        Ward             House_type          Legal  Floors  \
# 0      Cầu Giấy    Nghĩa Đô           Nhà ngõ, hẻm       Đã có sổ     4.0
# 1    Thanh Xuân   Kim Giang  Nhà mặt phố, mặt tiền  Dang_cap_nhat     5.0
# 2  Hai Bà Trưng   Minh Khai           Nhà ngõ, hẻm       Đã có sổ     4.0
# 3        Tây Hồ   Thụy Khuê           Nhà ngõ, hẻm       Đã có sổ     5.0
# 4    Thanh Xuân   Kim Giang           Nhà ngõ, hẻm  Dang_cap_nhat     5.0
# 5      Cầu Giấy     Yên Hoà           Nhà ngõ, hẻm       Đã có sổ     5.0
# 6       Đống Đa  Trung Liệt           Nhà ngõ, hẻm  Dang_cap_nhat     5.0
# 7  Hai Bà Trưng    Đống Mác  Nhà mặt phố, mặt tiền       Đã có sổ     6.0
# 8        Tây Hồ     Xuân La           Nhà ngõ, hẻm  Dang_cap_nhat     5.0
# 9       Hà Đông    Văn Quán           Nhà ngõ, hẻm       Đã có sổ     4.0
#
#    Bedrooms  Area  Price_per_m2  Total_Price_Billion
# 0       5.0  46.0         86.96              4.00016
# 1       3.0  37.0        116.22              4.30014
# 2       4.0  40.0         65.00              2.60000
# 3       6.0  51.0        100.00              5.10000
# 4       4.0  36.0         86.11              3.09996
# 5      10.0  46.0        104.35              4.80010
# 6       3.0  52.0        112.50              5.85000
# 7       5.0  32.0        184.38              5.90016
# 8       4.0  75.0        120.00              9.00000
# 9       3.0  41.0         64.63              2.64983

# %%
# 1. Lưu và mã hóa District
df['District_old'] = df['District'].copy()
df['District'] = pd.factorize(df['District'])[0]

print("--- BẢNG TRA CỨU DISTRICT ---")
district_map = df[['District_old', 'District']].drop_duplicates().sort_values('District')
print(district_map.to_string(index=False)) # Dùng to_string để hiện thị đẹp hơn
# Out:
# --- BẢNG TRA CỨU DISTRICT ---
#     District_old  District
#              NaN        -1
#         Cầu Giấy         0
#       Thanh Xuân         1
#     Hai Bà Trưng         2
#           Tây Hồ         3
#          Đống Đa         4
#          Hà Đông         5
#  Huyện Thanh Trì         6
#        Hoàng Mai         7
#        Long Biên         8
#        Hoàn Kiếm         9
#      Nam Từ Liêm        10
#          Ba Đình        11
#   Huyện Hoài Đức        12
#      Bắc Từ Liêm        13
# Huyện Đan Phượng        14
#  Huyện Thanh Oai        15
#    Huyện Sóc Sơn        16
#    Huyện Gia Lâm        17
#  Huyện Chương Mỹ        18
#   Huyện Đông Anh        19
# Huyện Thường Tín        20
#   Thị xã Sơn Tây        21
#    Huyện Mê Linh        22
#   Huyện Quốc Oai        23
#   Huyện Phúc Thọ        24
#  Huyện Phú Xuyên        25
#      Huyện Ba Vì        26
# Huyện Thạch Thất        27
#     Huyện Mỹ Đức        28

# %%
# 2. Lưu và mã hóa Ward
df['Ward_old'] = df['Ward'].copy()
df['Ward'] = pd.factorize(df['Ward'])[0]

print("--- BẢNG TRA CỨU WARD ---")
ward_map = df[['Ward_old', 'Ward']].drop_duplicates().sort_values('Ward')
print(ward_map.to_string(index=False))
# Out:
# --- BẢNG TRA CỨU WARD ---
#            Ward_old  Ward
#                 NaN    -1
#            Nghĩa Đô     0
#           Kim Giang     1
#           Minh Khai     2
#           Thụy Khuê     3
#             Yên Hoà     4
#          Trung Liệt     5
#            Đống Mác     6
#             Xuân La     7
#            Văn Quán     8
#   Thị trấn Văn Điển     9
#           Định Công    10
#               Bồ Đề    11
#         Quang Trung    12
#         Thanh Lương    13
#        Khương Trung    14
#            Phúc Tân    15
#            Gia Thụy    16
#         Khương Đình    17
#         Phương Canh    18
#           Tương Mai    19
#              La Khê    20
#              Mễ Trì    21
#          Khương Mai    22
#             Láng Hạ    23
#            Quan Hoa    24
#              Tây Mỗ    25
#          Ngọc Khánh    26
#              Đại Mỗ    27
#        Tả Thanh Oai    28
#           Mỹ Đình 1    29
#            Tam Hiệp    30
#             Cống Vị    31
#           Bách Khoa    32
#           Vĩnh Phúc    33
#           Kim Chung    34
#             Đại Kim    35
#            Mai Động    36
#            Trung Tự    37
#           Kiến Hưng    38
#           Trúc Bạch    39
#           Cổ Nhuế 1    40
#           Đức Giang    41
#           Mỹ Đình 2    42
#                Bưởi    43
#           Ô Chợ Dừa    44
#           Long Biên    45
#            Mai Dịch    46
#       Hoàng Văn Thụ    47
#          Nhân Chính    48
#            Vạn Phúc    49
#             Ngọc Hà    50
#            Lĩnh Nam    51
#           Xuân Đỉnh    52
#              Phú Đô    53
#           Liễu Giai    54
#      Thị trấn Phùng    55
#            Kim Liên    56
#           Phúc Diễn    57
#              Kim Mã    58
#         Trung Phụng    59
#             Tân Mai    60
#            Cầu Diễn    61
#           Ngã Tư Sở    62
#           Trung Văn    63
#         Thượng Đình    64
#          Hoàng Liệt    65
#          Thịnh Liệt    66
#        Quốc Tử Giám    67
#         Trương Định    68
#          Khâm Thiên    69
#            Phú Diễn    70
#           Thạch Bàn    71
#           Ngọc Thụy    72
#             Cầu Dền    73
#           Phú Lương    74
#           Bạch Đằng    75
#              Phú La    76
#              Hà Cầu    77
#         Láng Thượng    78
#         Phương Liệt    79
#           Vĩnh Hưng    80
#          Thanh Nhàn    81
#             Cự Khối    82
#             Đội Cấn    83
#         Thịnh Quang    84
#           Trung Hoà    85
#           Quỳnh Mai    86
#            Nam Đồng    87
#       Dịch Vọng Hậu    88
#           Nghĩa Tân    89
#              Cự Khê    90
#            Vĩnh Tuy    91
#           Yên Nghĩa    92
#          Thành Công    93
#            Giáp Bát    94
#           Dịch Vọng    95
#      Thanh Xuân Bắc    96
#          Phương Mai    97
#            Bạch Mai    98
#           Thanh Trì    99
#        Thượng Thanh   100
#            Trần Phú   101
#         Nguyễn Trãi   102
#           Dương Nội   103
#             Hạ Đình   104
#      Thanh Xuân Nam   105
#            Vân Canh   106
#              Phù Lỗ   107
#             Phố Huế   108
#            Đồng Tâm   109
#         Xuân Phương   110
#        Phạm Đình Hổ   111
#              La Phù   112
#            Ngọc Lâm   113
#              Mộ Lao   114
#          Phú Thượng   115
#           Việt Hưng   116
#           Đông Ngạc   117
#            Thổ Quan   118
#         Lê Đại Hành   119
#       Khương Thượng   120
#             Phú Lãm   121
#               Cổ Bi   122
#          Biên Giang   123
#            Hàng Bột   124
#           Cổ Nhuế 2   125
#            Giảng Võ   126
#   Thị trấn Chúc Sơn   127
#             Kiêu Kỵ   128
#            Cát Linh   129
#           Quỳnh Lôi   130
#              Yên Sở   131
#             Đặng Xá   132
#            Yết Kiêu   133
#            Cửa Đông   134
#          Giang Biên   135
#        Chương Dương   136
#             Phúc La   137
#           Phúc Đồng   138
#          Thượng Cát   139
#             Phúc Xá   140
#          Văn Chương   141
#             Tứ Hiệp   142
#             Đông Dư   143
#    Thanh Xuân Trung   144
#         Phương Liên   145
#            Nhật Tân   146
#  Thị trấn Trạm Trôi   147
#            Sài Đồng   148
#           Tân Triều   149
#            Văn Miếu   150
#            Đông Hội   151
#          Phụng Châu   152
#            Quảng An   153
#   Thị trấn Trâu Quỳ   154
#          Quán Thánh   155
#            Phúc Lợi   156
#             Hữu Hoà   157
#           Đồng Nhân   158
#        Ngô Thì Nhậm   159
#            Đồng Mai   160
#             Đông La   161
#            Liên Mạc   162
#            Ngọc Hồi   163
#        Bùi Thị Xuân   164
#            Xuân Tảo   165
#             Yên Phụ   166
#          Thanh Liệt   167
#         Thụy Phương   168
#           Hàng Bông   169
#        Nghiêm Xuyên   170
#           Nguyễn Du   171
#             Tứ Liên   172
#      Phan Chu Trinh   173
#          Vĩnh Quỳnh   174
#             Cửa Nam   175
#            Di Trạch   176
#             Võng La   177
#           Điện Biên   178
#            Bắc Hồng   179
#             Hải Bối   180
#             Đại Yên   181
#           Ngô Quyền   182
#       Trần Hưng Đạo   183
#           Liên Ninh   184
#            Hàng Bài   185
#             Đông Mỹ   186
#           Đức Thắng   187
#          Tràng Tiền   188
#            Hàng Bạc   189
#            Ngũ Hiệp   190
#          Yên Thường   191
#            Duyên Hà   192
#           Đồng Xuân   193
#            An Khánh   194
#   Thị trấn Yên Viên   195
#           Hàng Buồm   196
#             Lại Yên   197
#            Bích Hòa   198
# Thị trấn Quang Minh   199
#    Thị trấn Kim Bài   200
#            Khánh Hà   201
#             Tây Tựu   202
#              Kim Nỗ   203
#             Tân Lập   204
#             Hàng Mã   205
#           Phú Cường   206
#              Đa Tốn   207
#             Hàng Bồ   208
#           An Thượng   209
#            Minh Phú   210
#   Nguyễn Trung Trực   211
#          Lý Thái Tổ   212
#   Thị trấn Quốc Oai   213
# Thị trấn Thường Tín   214
#           Phú Thịnh   215
#             Đại áng   216
#          Võng Xuyên   217
#  Thị trấn Phú Xuyên   218
#              Hà Hồi   219
#            Phú Châu   220
#             Cổ Đông   221
#             Vân Côn   222
#            Tam Đồng   223
#         Dương Quang   224
#   Thị trấn Đông Anh   225
#            Đông Yên   226
#             Vân Nội   227
#           Tiên Dược   228
#          Hương Ngải   229
#           Ngọc Liệp   230
#             Nhị Khê   231
#   Thị trấn Xuân Mai   232
#           Bát Tràng   233
#            Hàng Đào   234
#            Nam Hồng   235
#            Tam Hưng   236
#          Nguyên Khê   237
#             Sài Sơn   238
#           Ninh Hiệp   239
#               Uy Nỗ   240
#            Viên Sơn   241
#             Ninh Sở   242
#        Phương Trung   243
#            Đại Mạch   244
#             Kim Sơn   245
#          Duyên Thái   246
#      Trung Sơn Trầm   247
#            Dương Xá   248
#            Xuân Nộn   249
#           Việt Hùng   250
#            Văn Bình   251
#            Hàng Gai   252
#           Thanh Cao   253
#            Mai Đình   254
#           Đông Xuân   255
#             Mai Lâm   256
#            Sơn Đồng   257
#                 Tân   258
#           Thượng Mỗ   259
#         Nghĩa Hương   260
#          Dương Liễu   261
#          Đức Thượng   262
#          Hàng Trống   263
#             Kim Hoa   264
#          Tiền Phong   265
#            Bình Phú   266
#              Dục Tú   267
#            Yên Viên   268
#          Đồng Quang   269
#          Quang Tiến   270
#            Sơn Đông   271
#           Đại Thành   272
#            Phù Linh   273
#             Đỗ Động   274
#            Phú Minh   275
#           Hợp Thanh   276
#             Tân Hội   277
#          Thanh Xuân   278
#         Song Phương   279
#           Vĩnh Ngọc   280
#              Lê Lợi   281
#    Thị trấn Sóc Sơn   282
#  Thị trấn Liên Quan   283
#             Mê Linh   284
#          Đan Phượng   285
#           Thạch Hoà   286
#             Vân Tảo   287
#          Xuân Khanh   288
#            Phù Đổng   289
#             Phú Sơn   290
#             Phú Cát   291
#            Ngọc Tảo   292
#         Phương Đình   293

# %%
# 3. Lưu và mã hóa House_type
df['House_type_old'] = df['House_type'].copy()
df['House_type'] = pd.factorize(df['House_type'])[0]

print("--- BẢNG TRA CỨU HOUSE_TYPE ---")
house_type_map = df[['House_type_old', 'House_type']].drop_duplicates().sort_values('House_type')
print(house_type_map.to_string(index=False))
# Out:
# --- BẢNG TRA CỨU HOUSE_TYPE ---
#        House_type_old  House_type
#                   NaN          -1
#          Nhà ngõ, hẻm           0
# Nhà mặt phố, mặt tiền           1
#          Nhà biệt thự           2
#       Nhà phố liền kề           3

# %%
# 4. Lưu và mã hóa Legal
df['Legal_old'] = df['Legal'].copy()
df['Legal'] = pd.factorize(df['Legal'])[0]

print("--- BẢNG TRA CỨU LEGAL ---")
legal_map = df[['Legal_old', 'Legal']].drop_duplicates().sort_values('Legal')
print(legal_map.to_string(index=False))
# Out:
# --- BẢNG TRA CỨU LEGAL ---
#     Legal_old  Legal
#      Đã có sổ      0
# Dang_cap_nhat      1
#   Đang chờ sổ      2
#  Giấy tờ khác      3

# %%
df
# Out:
#        District  Ward  House_type  Legal  Floors  Bedrooms  Area  \
# 0             0     0           0      0     4.0       5.0  46.0
# 1             1     1           1      1     5.0       3.0  37.0
# 2             2     2           0      0     4.0       4.0  40.0
# 3             3     3           0      0     5.0       6.0  51.0
# 4             1     1           0      1     5.0       4.0  36.0
# ...         ...   ...         ...    ...     ...       ...   ...
# 82491        13    57           3      1     5.0       3.0  38.0
# 82492         0    24           1      1     5.0       3.0  50.0
# 82493         0    24           1      0     5.0       4.0  41.0
# 82494         0    24           0      0     5.0       4.0  60.0
# 82495         0    46           3      1     5.0       4.0  45.0
#
#        Price_per_m2  Total_Price_Billion  District_old   Ward_old  \
# 0             86.96              4.00016      Cầu Giấy   Nghĩa Đô
# 1            116.22              4.30014    Thanh Xuân  Kim Giang
# 2             65.00              2.60000  Hai Bà Trưng  Minh Khai
# 3            100.00              5.10000        Tây Hồ  Thụy Khuê
# 4             86.11              3.09996    Thanh Xuân  Kim Giang
# ...             ...                  ...           ...        ...
# 82491         81.58              3.10004   Bắc Từ Liêm  Phúc Diễn
# 82492        292.00             14.60000      Cầu Giấy   Quan Hoa
# 82493        341.46             13.99986      Cầu Giấy   Quan Hoa
# 82494        101.67              6.10020      Cầu Giấy   Quan Hoa
# 82495        102.22              4.59990      Cầu Giấy   Mai Dịch
#
#               House_type_old      Legal_old
# 0               Nhà ngõ, hẻm       Đã có sổ
# 1      Nhà mặt phố, mặt tiền  Dang_cap_nhat
# 2               Nhà ngõ, hẻm       Đã có sổ
# 3               Nhà ngõ, hẻm       Đã có sổ
# 4               Nhà ngõ, hẻm  Dang_cap_nhat
# ...                      ...            ...
# 82491        Nhà phố liền kề  Dang_cap_nhat
# 82492  Nhà mặt phố, mặt tiền  Dang_cap_nhat
# 82493  Nhà mặt phố, mặt tiền       Đã có sổ
# 82494           Nhà ngõ, hẻm       Đã có sổ
# 82495        Nhà phố liền kề  Dang_cap_nhat
#
# [81825 rows x 13 columns]

# %%
df = df.drop(columns=['District_old', 'Ward_old', 'House_type_old', 'Legal_old'])

# %%
df
# Out:
#        District  Ward  House_type  Legal  Floors  Bedrooms  Area  \
# 0             0     0           0      0     4.0       5.0  46.0
# 1             1     1           1      1     5.0       3.0  37.0
# 2             2     2           0      0     4.0       4.0  40.0
# 3             3     3           0      0     5.0       6.0  51.0
# 4             1     1           0      1     5.0       4.0  36.0
# ...         ...   ...         ...    ...     ...       ...   ...
# 82491        13    57           3      1     5.0       3.0  38.0
# 82492         0    24           1      1     5.0       3.0  50.0
# 82493         0    24           1      0     5.0       4.0  41.0
# 82494         0    24           0      0     5.0       4.0  60.0
# 82495         0    46           3      1     5.0       4.0  45.0
#
#        Price_per_m2  Total_Price_Billion
# 0             86.96              4.00016
# 1            116.22              4.30014
# 2             65.00              2.60000
# 3            100.00              5.10000
# 4             86.11              3.09996
# ...             ...                  ...
# 82491         81.58              3.10004
# 82492        292.00             14.60000
# 82493        341.46             13.99986
# 82494        101.67              6.10020
# 82495        102.22              4.59990
#
# [81825 rows x 9 columns]

# %%
df.to_csv('C:/Users/Admin/Downloads/data/processed/clean_vn_housing.csv', index=False)
